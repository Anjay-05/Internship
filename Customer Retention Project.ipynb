# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel("customer retention dataset.xlsx")
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
#Checking column names
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
#Renaming the column names
df.rename({'2 How old are you? ':'2 How old are you?','9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ':'9 What is the screen size of your mobile device?','10 What is the operating system (OS) of your device?\t\t\t\t                                          ':'10 What is the operating system (OS) of your device?','11 What browser do you run on your device to access the website?\t\t\t                                                          ':'11 What browser do you run on your device to access the website?','12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ':'12 Which channel did you follow to arrive at your favorite online store for the first time?','13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ':'13 After first visit, how do you reach the online retail store?','14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ':'14 How much time do you explore the e- retail store before making a purchase decision?','15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ':'15 What is your preferred payment Option?','16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ':'16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?','17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ':'17 Why did you abandon the “Bag”, “Shopping Cart”?','From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ':'From the following, tick any (or all) of the online retailers you have shopped from;'},axis=1,inplace=True)
df.tail()
# Out:
#     1Gender of respondent  2 How old are you?  \
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# ...

# %%
df.shape
# Out:
# (269, 71)

# %% [markdown]
# The dataset has 269 rows and 71 columns.

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you?',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?',
#        '10 What is the operating system (OS) of your device?',
#        '11 What browser do you run on your device to access the website?',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?',
#        '13 After first visit, how do you reach the online retail store?',
#        '14 How much time do you explore the e- retail store before making a purchase decision?',
#        '15 What is your preferred payment Option?',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                        --------------  -----
#  0   1Gender of respondent                                                                                         269 non-null    object
#  1   2 How old are you?                                                                                            269 non-null    object
#  2   3 Which city do you shop online from?                                                                         269 non-null    object
#  3   4 What is the Pin Code of where you shop online from?                                                         269 non-null    int64
# ...

# %% [markdown]
# The dataframe has 269 rows and 71 columns.
#
# The data types in the columns are integer and object.

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no null value in the dataframe.

# %% [markdown]
# Data Visuallization

# %%
#Univariate
i=df['1Gender of respondent']
plt.figure(figsize=(10,5))
sns.countplot(i)
i.value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %% [markdown]
# From the total 269 data entries, 181 is from Females and 88 from females.

# %%
i=df['2 How old are you?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you?, dtype: int64

# %% [markdown]
# The age of the 81 entries in between 31-40 years, 79 entries in between 21-30 years, 70 entries in between 41-50 years 20 entries in less than 20 years and 19 entries in 51 years & above.

# %%
i=df['3 Which city do you shop online from?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# Most of them shop online from the cities like Delhi,Noida and Banglore. Least purchase from Merrut,Moradabad and Bulandshahr.

# %%
i=df['4 What is the Pin Code of where you shop online from?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 173212     9
# 250001     9
# 122018     8
# 560037     8
# 132036     8
# 560010     8
# 110011     7
# 110008     7
# 201306     7
# 110014     6
# 110018     6
# 201008     5
# 201009     5
# 201305     5
# 201312     5
# 244001     5
# 530068     5
# 201005     4
# 110009     4
# 110042     4
# 110039     4
# 110030     4
# 201304     4
# 122009     4
# 201303     4
# 560018     4
# 201001     4
# 560003     4
# 560002     4
# 560013     3
# 203001     2
# 203207     1
# 560001     1
# 203202     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %%
i=df['5 Since How Long You are Shopping Online ?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %% [markdown]
# 98 of the entries are shopping from online above 4 years,65 entries are shopping from online for 2-3 year, 47 entries since 3-4 years,43 entries less than 1 year and 16 entries from 1-2 years.

# %%
i=df['6 How many times you have made an online purchase in the past 1 year?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %%
i=df['7 How do you access the internet while shopping on-line?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# 189 users using Mobile internet for online shopping, 76 users using wifi and 4 users using Dial-up.

# %%
i=df['8 Which device do you use to access the online shopping?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# 141 users access online shopping using smartphone, 86 users using laptops, 30 users using Desktop and 12 users using Tablets.

# %%
i=df['9 What is the screen size of your mobile device?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?, dtype: int64

# %% [markdown]
# 7 users using 5 inches screen size device,29 users using 4.7 inches device,99 users using 5.5 inches device and 134 users using other inches devices.

# %%
i=df['10 What is the operating system (OS) of your device?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?, dtype: int64

# %% [markdown]
# 122 Users using Window/windows Mobile OS, 85 users using Android and 62 users using IOS/Mac.

# %%
i=df['11 What browser do you run on your device to access the website?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?, dtype: int64

# %% [markdown]
# The websites are accessed by users using different browser like Google chrome,Safari,Opera and Mozilla Firefox.216 of them use Google chrome,40 of them use safari,8 of them use opera and 5 of them use Mozilla firefox.

# %%
i=df['12 Which channel did you follow to arrive at your favorite online store for the first time?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?, dtype: int64

# %% [markdown]
# 230 of them use search engine,20 of them use cotent marketing and 19 use display adverts to arrive at online store.

# %%
i=df['13 After first visit, how do you reach the online retail store?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?, dtype: int64

# %%
i=df['14 How much time do you explore the e- retail store before making a purchase decision?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?, dtype: int64

# %%
i=df['15 What is your preferred payment Option?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?, dtype: int64

# %% [markdown]
# 148 users prefer payment using Credit/Debit cards, 76 users prefer cash on delivery and 45 users prefer E-wallets.

# %%
i=df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?, dtype: int64

# %%
i=df['17 Why did you abandon the “Bag”, “Shopping Cart”?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?, dtype: int64

# %% [markdown]
# 133 users abandoning the shopping cart because of better alternative offer,54 users face issue with Promo code, 37 due to change in price, 31 user because of lack of trust and 14 users because no preferred mode of payment.

# %%
i=df['18 The content on the website must be easy to read and understand']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %% [markdown]
# 164 users strongly agree that content on the website must be easy to read and understand,80 users also agree, but 18 users strongly disagree and 7 user have indifferent.

# %%
i=df['19 Information on similar product to the one highlighted  is important for product comparison']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %%
i=df['20 Complete information on listed seller and product being offered is important for purchase decision.']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %%
i=df['21 All relevant information on listed products must be stated clearly']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %%
i=df['22 Ease of navigation in website']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %%
i=df['23 Loading and processing speed']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Indifferent (3)           12
# Strongly disagree (1)     12
# Name: 23 Loading and processing speed, dtype: int64

# %%
i=df['24 User friendly Interface of the website']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %%
i=df['25 Convenient Payment methods']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %%
i=df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %%
i=df['27 Empathy (readiness to assist with queries) towards the customers']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %%
i=df['28 Being able to guarantee the privacy of the customer']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %%
i=df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %%
i=df['30 Online shopping gives monetary benefit and discounts']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %%
i=df['31 Enjoyment is derived from shopping online']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %%
i=df['32 Shopping online is convenient and flexible']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %%
i=df['33 Return and replacement policy of the e-tailer is important for purchase decision']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %%
i=df['34 Gaining access to loyalty programs is a benefit of shopping online']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)       115
# indifferent (3)           64
# Agree (4)                 64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %%
i=df['35 Displaying quality Information on the website improves satisfaction of customers']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %%
i=df['36 User derive satisfaction while shopping on a good quality website or application']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %%
i=df['37 Net Benefit derived from shopping online can lead to users satisfaction']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %%
i=df['38 User satisfaction cannot exist without trust']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %%
i=df['39 Offering a wide variety of listed product in several category']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %%
i=df['40 Provision of complete and relevant product information']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %%
i=df['41 Monetary savings']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %%
i=df['42 The Convenience of patronizing the online retailer']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %%
i=df['43 Shopping on the website gives you the sense of adventure']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %%
i=df['44 Shopping on your preferred e-tailer enhances your social status']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %%
i=df['45 You feel gratification shopping on your favorite e-tailer']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %%
i=df['46 Shopping on the website helps you fulfill certain roles']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# indifferent (3)          88
# Agree (4)                88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %%
i=df['47 Getting value for money spent']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %%
i=df['From the following, tick any (or all) of the online retailers you have shopped from;']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;, dtype: int64

# %%
i=df['Easy to use website or application']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com                                         44
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %%
i=df['Visual appealing web-page layout']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Myntra.com                                                      15
# Amazon.in, Myntra.com                                           15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout, dtype: int64

# %%
i=df['Wild variety of product on offer']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Myntra.com                                            15
# Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %%
i=df['Complete, relevant description information of products']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %%
i=df['Fast loading website speed of website and application']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %%
i=df['Reliability of the website or application']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Flipkart.com                                         15
# Myntra.com                                           15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %%
i=df['Quickness to complete purchase']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Flipkart.com                                                 15
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %%
i=df['Availability of several payment options']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %%
i=df['Speedy order delivery ']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Flipkart.com                               15
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %%
i=df['Privacy of customers’ information']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Flipkart.com                                                    15
# Amazon.in, Paytm.com                                            15
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64

# %%
i=df['Security of customer financial information']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Myntra.com                                                      15
# Paytm.com                                                       15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %%
i=df['Perceived Trustworthiness']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %%
i=df['Presence of online assistance through multi-channel']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %%
i=df['Longer time to get logged in (promotion, sales period)']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in                                57
# Amazon.in, Flipkart.com                  38
# Paytm.com                                38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %%
i=df['Longer time in displaying graphics and photos (promotion, sales period)']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Flipkart.com                           15
# Paytm.com                              15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %%
i=df['Late declaration of price (promotion, sales period)']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Amazon.in                  38
# Flipkart.com               38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %%
i=df['Longer page loading time (promotion, sales period)']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %%
i=df['Limited mode of payment on most products (promotion, sales period)']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
i=df['Longer delivery period']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Myntra.com                 26
# Paytm.com, Snapdeal.com    26
# Name: Longer delivery period, dtype: int64

# %%
i=df['Change in website/Application design']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64

# %%
i=df['Frequent disruption when moving from one page to another']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %%
i=df['Website is as efficient as before']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %%
i=df['Which of the Indian online retailer would you recommend to a friend?']
plt.figure(figsize=(12,5))
sns.countplot(i)
i.value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %%
#Bivariate
plt.figure(figsize=(12,5))
sns.countplot(x='2 How old are you?',hue='1Gender of respondent',data=df)
# Out:
# <AxesSubplot:xlabel='2 How old are you?', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='3 Which city do you shop online from?',hue='2 How old are you?',data=df)
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='6 How many times you have made an online purchase in the past 1 year?',hue='2 How old are you?',data=df)
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(x='1Gender of respondent',hue='7 How do you access the internet while shopping on-line?',data=df)

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(x='8 Which device do you use to access the online shopping?',hue='7 How do you access the internet while shopping on-line?',data=df)

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(x='10 What is the operating system (OS) of your device?',hue='8 Which device do you use to access the online shopping?',data=df)

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(hue='15 What is your preferred payment Option?',x='8 Which device do you use to access the online shopping?',data=df)

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(x='11 What browser do you run on your device to access the website?',hue='10 What is the operating system (OS) of your device?',data=df)

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(x='15 What is your preferred payment Option?',hue='2 How old are you?',data=df)

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(x='6 How many times you have made an online purchase in the past 1 year?',hue='18 The content on the website must be easy to read and understand',data=df)

# %% [markdown]
# Conclusion

# %% [markdown]
# From the collected data the customers looking for the E-commerce store with best serivce,best information quality,trustful,user friendly,best payment methods,fastest delivery,best offers and privacy scurity.
